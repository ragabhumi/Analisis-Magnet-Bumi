# %% [markdown]
# <a href="https://colab.research.google.com/github/ragabhumi/Analisis-Magnet-Bumi/blob/main/Pemodelan_Gayaberat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktek processing data magnet bumi
#
# Pelatihan Earth Imaging

# %% [markdown]
# Instal CondaColab di Google Colab

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %% [markdown]
# Cek apakah instalasi CondaColab berhasil

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# Instal modul-modul yang diperlukan

# %%
# !mamba install verde harmonica boule pooch pygmt pyproj pandas xarray
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# ...

# %% [markdown]
# Import modul-modul Python

# %%
# The standard Python science stack
import numpy as np
import pandas as pd
import xarray as xr

# For projections (wrapped for Proj)
import pyproj

# Plotting maps using GMT
import pygmt

# The Fatiando stack
import pooch
import verde as vd
import boule as bl
import harmonica as hm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5e4e22ce7abd> in <cell line: 7>()
#       5
#       6 # For projections (wrapped for Proj)
# ----> 7 import pyproj
#       8
#       9 # Plotting maps using GMT
#
# ModuleNotFoundError: No module named 'pyproj'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Import data survey

# %%
url_mag = 'https://raw.githubusercontent.com/ragabhumi/Pelatihan_Earth_Imaging/main/data/data_survey.txt'
sha='sha256:98082e487f642b0ed36e1a4fd1bacff1cf53905154b93811a910b3f1cc05715e'
path_mag = pooch.retrieve(url_mag, known_hash=sha)
print(path_mag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ca1997fb001> in <cell line: 3>()
#       1 url_mag = 'https://raw.githubusercontent.com/ragabhumi/Pelatihan_Earth_Imaging/main/data/data_survey.txt'
#       2 sha='sha256:98082e487f642b0ed36e1a4fd1bacff1cf53905154b93811a910b3f1cc05715e'
# ----> 3 path_mag = pooch.retrieve(url_mag, known_hash=sha)
#       4 print(path_mag)
#
# NameError: name 'pooch' is not defined

# %%
data = pd.read_csv(path_mag, sep='\t')
data['Waktu1'] = pd.to_datetime(data['Waktu1'], format='%Y-%m-%d %H:%M:%S')
data['Waktu2'] = pd.to_datetime(data['Waktu2'], format='%Y-%m-%d %H:%M:%S')
data['Waktu3'] = pd.to_datetime(data['Waktu3'], format='%Y-%m-%d %H:%M:%S')

data
# Out:
#     Titik  Latitude  Longitude   Keterangan              Waktu1
# 0    A.27   9225320     672794  Dekat Pagar 2022-04-21 23:47:15  \
# 1    A.29   9225310     672809            - 2022-04-21 23:55:48
# 2    A.01   9225500     672611            - 2022-04-22 00:45:25
# 3    A.02   9225500     672618            - 2022-04-22 00:43:37
# 4    A.06   9225470     672646            - 2022-04-22 00:36:32
# ..    ...       ...        ...          ...                 ...
# 362  S.27   9225190     672667            - 2022-04-24 00:04:03
# 363  S.28   9225190     672674            - 2022-04-24 00:01:39
# 364  T.26   9225189     672656            - 2022-04-24 00:07:45
# 365  T.27   9225190     672659            - 2022-04-24 00:09:29
# 366  T.28   9225180     672667            - 2022-04-24 00:11:10
#
#                  Waktu2              Waktu3        F1        F2        F3
# 0   2022-04-21 23:47:25 2022-04-21 23:47:35  44551.44       NaN  44550.82
# ...

# %% [markdown]
# Hitung rata-rata waktu dan rata-rata nilai pembacaan proton

# %%
data['Waktu_rata'] = data.loc[:, ['Waktu1', 'Waktu2', 'Waktu3']].mean(axis=1).dt.strftime('%Y-%m-%d %H:%M:%S')
data['F_rata'] = data.loc[:, ['F1', 'F2', 'F3']].mean(axis=1).map('{:.2f}'.format)
data
# Out:
#     Titik  Latitude  Longitude   Keterangan              Waktu1
# 0    A.27   9225320     672794  Dekat Pagar 2022-04-21 23:47:15  \
# 1    A.29   9225310     672809            - 2022-04-21 23:55:48
# 2    A.01   9225500     672611            - 2022-04-22 00:45:25
# 3    A.02   9225500     672618            - 2022-04-22 00:43:37
# 4    A.06   9225470     672646            - 2022-04-22 00:36:32
# ..    ...       ...        ...          ...                 ...
# 362  S.27   9225190     672667            - 2022-04-24 00:04:03
# 363  S.28   9225190     672674            - 2022-04-24 00:01:39
# 364  T.26   9225189     672656            - 2022-04-24 00:07:45
# 365  T.27   9225190     672659            - 2022-04-24 00:09:29
# 366  T.28   9225180     672667            - 2022-04-24 00:11:10
#
#                  Waktu2              Waktu3        F1        F2        F3
# 0   2022-04-21 23:47:25 2022-04-21 23:47:35  44551.44       NaN  44550.82  \
# ...

# %% [markdown]
# Import data proton base ngetes
